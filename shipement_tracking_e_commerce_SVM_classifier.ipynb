# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder
import pickle
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.utils import resample
from sklearn.preprocessing import scale
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA

# %%
from google.colab import drive
drive.mount('/content/Drive')
# Out:
# Mounted at /content/Drive

# %%
############## SVM ##############
#étape 1 : la  lecture et la compréhension des données 

df = pd.read_csv("/content/Drive/MyDrive/e-comerce dataset/data.csv")
df.head()
# Out:
#    ID Warehouse_block  ... Weight_in_gms  Reached.on.Time_Y.N
# 0   1               D  ...          1233                    1
# 1   2               F  ...          3088                    1
# 2   3               A  ...          3374                    1
# 3   4               B  ...          1177                    1
# 4   5               C  ...          2484                    1
#
# [5 rows x 12 columns]

# %%
#Compter les valeurs de classe pour voir la répartition entre 1 (produit arrivé) et 0(produit n'est pas arrivé )
sizes = df['Reached.on.Time_Y.N'].value_counts(sort = 1)
print(sizes)
# Out:
# 1    6563
# 0    4436
# Name: Reached.on.Time_Y.N, dtype: int64

# %%
#la proportion de chaque étiquette
plt.pie(sizes, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7ff4c134ce10>,
#   <matplotlib.patches.Wedge at 0x7ff4c135d650>],
#  [Text(-0.3290237775458344, 1.0496396304491695, ''),
#   Text(0.3290237775458339, -1.0496396304491697, '')],
#  [Text(-0.17946751502500058, 0.5725307075177288, '59.7%'),
#   Text(0.17946751502500027, -0.5725307075177289, '40.3%')])

# %%
#étape 1.5
#dans les prochains cas, nous allons explorer nos données
#cette ligne nous montre quelques informations sur notre jeu de données
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10999 non-null  object
#  3   Customer_care_calls  10999 non-null  int64
#  4   Customer_rating      10999 non-null  int64
#  5   Cost_of_the_Product  10999 non-null  int64
#  6   Prior_purchases      10999 non-null  int64
#  7   Product_importance   10999 non-null  object
#  8   Gender               10999 non-null  object
#  9   Discount_offered     10999 non-null  int64
#  10  Weight_in_gms        10999 non-null  int64
#  11  Reached.on.Time_Y.N  10999 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 1.0+ MB

# %%
#puisque l'ID est une information non pertinente, nous devons le supprimer de l'ensemble de données
df.drop(['ID'], axis=1, inplace=True)
df.head()
# Out:
#   Warehouse_block Mode_of_Shipment  ...  Weight_in_gms  Reached.on.Time_Y.N
# 0               D           Flight  ...           1233                    1
# 1               F           Flight  ...           3088                    1
# 2               A           Flight  ...           3374                    1
# 3               B           Flight  ...           1177                    1
# 4               C           Flight  ...           2484                    1
#
# [5 rows x 11 columns]

# %%
#les trois cas suivants sont pour sous-échantillonner l'ensemble de données et rendre les deux classes égales afin que le modèle s'entraîne sur les deux classes de manière égale
df_reached = df[df['Reached.on.Time_Y.N'] == 0]
df_not_reached = df[df['Reached.on.Time_Y.N'] == 1]

# %%
df_reached_downsampled = resample(df_reached,replace=False,n_samples=4000,random_state=25) 
df_not_reached_downsampled = resample(df_not_reached,replace=False,n_samples=4000,random_state=25)

# %%
df_downsampled = pd.concat([df_not_reached_downsampled,df_reached_downsampled])
print(len(df_downsampled))
# Out:
# 8000

# %%
sizes2 = df_downsampled['Reached.on.Time_Y.N'].value_counts(sort = 1)
print(sizes2)
plt.pie(sizes2, autopct='%1.1f%%')
# Out:
# 1    4000
# 0    4000
# Name: Reached.on.Time_Y.N, dtype: int64
# ([<matplotlib.patches.Wedge at 0x7ff4c03a8190>,
#   <matplotlib.patches.Wedge at 0x7ff4c03a8910>],
#  [Text(6.735557395310444e-17, 1.1, ''),
#   Text(-2.0206672185931328e-16, -1.1, '')],
#  [Text(3.6739403974420595e-17, 0.6, '50.0%'),
#   Text(-1.1021821192326178e-16, -0.6, '50.0%')])

# %%
df_downsampled.head()
# Out:
#      Warehouse_block Mode_of_Shipment  ...  Weight_in_gms  Reached.on.Time_Y.N
# 2554               C             Ship  ...           2837                    1
# 2529               B             Ship  ...           1551                    1
# 1073               F             Road  ...           1053                    1
# 9432               D             Road  ...           1364                    1
# 2539               F             Ship  ...           2070                    1
#
# [5 rows x 11 columns]

# %%
X=df_downsampled.drop('Reached.on.Time_Y.N',axis=1).copy()
X.head()
# Out:
#      Warehouse_block Mode_of_Shipment  ...  Discount_offered  Weight_in_gms
# 2554               C             Ship  ...                23           2837
# 2529               B             Ship  ...                19           1551
# 1073               F             Road  ...                34           1053
# 9432               D             Road  ...                 2           1364
# 2539               F             Ship  ...                21           2070
#
# [5 rows x 10 columns]

# %%
y=df_downsampled['Reached.on.Time_Y.N'].copy()
y.head()
# Out:
# 2554    1
# 2529    1
# 1073    1
# 9432    1
# 2539    1
# Name: Reached.on.Time_Y.N, dtype: int64

# %%
df_downsampled.select_dtypes(['object'])
# Out:
#       Warehouse_block Mode_of_Shipment Product_importance Gender
# 2554                C             Ship             medium      F
# 2529                B             Ship                low      M
# 1073                F             Road             medium      M
# 9432                D             Road                low      F
# 2539                F             Ship                low      F
# ...               ...              ...                ...    ...
# 8144                A             Ship             medium      F
# 6242                A             Ship             medium      F
# 9839                F             Road                low      F
# 10643               F             Ship             medium      M
# 9138                D             Ship             medium      M
#
# [8000 rows x 4 columns]

# %%
#rendre les rcolonnes non numériques numériques avec le codage à chaud et le codeur d'étiquette
X_encoded=pd.get_dummies(X,columns=['Warehouse_block','Mode_of_Shipment'])
X_encoded.head()
# Out:
#       Customer_care_calls  ...  Mode_of_Shipment_Ship
# 2554                    5  ...                      1
# 2529                    2  ...                      1
# 1073                    3  ...                      0
# 9432                    6  ...                      0
# 2539                    2  ...                      1
#
# [5 rows x 16 columns]

# %%
label_encoder_data =X_encoded
label_encoder = LabelEncoder()
for col in X_encoded.select_dtypes(['object']):
  
  label_encoder_data[col] = label_encoder.fit_transform(label_encoder_data[col])
X_encoded = label_encoder_data

# %%
X_encoded.head()
# Out:
#       Customer_care_calls  ...  Mode_of_Shipment_Ship
# 2554                    5  ...                      1
# 2529                    2  ...                      1
# 1073                    3  ...                      0
# 9432                    6  ...                      0
# 2539                    2  ...                      1
#
# [5 rows x 16 columns]

# %%
#diviser les données 
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=35)

# %%
#créer le modèle de classificateur SVM
model=SVC(random_state=28)

# %%
#former le modèle
model.fit(X_train,y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=28, shrinking=True, tol=0.001,
#     verbose=False)

# %%
prediction_test = model.predict(X_test)

# %%
#Imprimer la précision de la prédiction
print ("Accuracy = ", metrics.accuracy_score(y_test, prediction_test))
# Out:
# Accuracy =  0.69

# %%
# comme la précision n'est que de 0,69 nous devons l'améliorer et pour cela nous allons utiliser la méthode de validation croisée

#ici, nous définissons les paramètres que nous allons essayer
       
param_grid = [
              {'C':[0.5,3,5,7,9,10,100],
              'gamma':['scale',1,0.1,0.01,0.001,0.0001],
               'kernel':['rbf']},
                       ]

# %%
#appliquer les paramètres ci-dessus sur un modèle
optimal_params = GridSearchCV(
    SVC(),
    param_grid,
    cv=10,
    scoring='accuracy',
    verbose=2
)

# %%
#entraîner le modèle sur les paramètres définis précédemment
optimal_params.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 42 candidates, totalling 420 fits
# [CV] C=0.5, gamma=scale, kernel=rbf ..................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................... C=0.5, gamma=scale, kernel=rbf, total=   1.7s
# [CV] C=0.5, gamma=scale, kernel=rbf ..................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [CV] ................... C=0.5, gamma=scale, kernel=rbf, total=   1.7s
# [CV] C=0.5, gamma=scale, kernel=rbf ..................................
# [CV] ................... C=0.5, gamma=scale, kernel=rbf, total=   1.7s
# [CV] C=0.5, gamma=scale, kernel=rbf ..................................
# [CV] ................... C=0.5, gamma=scale, kernel=rbf, total=   1.7s
# [CV] C=0.5, gamma=scale, kernel=rbf ..................................
# [CV] ................... C=0.5, gamma=scale, kernel=rbf, total=   1.7s
# [CV] C=0.5, gamma=scale, kernel=rbf ..................................
# [CV] ................... C=0.5, gamma=scale, kernel=rbf, total=   1.7s
# [CV] C=0.5, gamma=scale, kernel=rbf ..................................
# [CV] ................... C=0.5, gamma=scale, kernel=rbf, total=   1.7s
# [CV] C=0.5, gamma=scale, kernel=rbf ..................................
# [CV] ................... C=0.5, gamma=scale, kernel=rbf, total=   1.8s
# [CV] C=0.5, gamma=scale, kernel=rbf ..................................
# [CV] ................... C=0.5, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=0.5, gamma=scale, kernel=rbf ..................................
# [CV] ................... C=0.5, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=0.5, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=0.5, gamma=1, kernel=rbf, total=   2.7s
# [CV] C=0.5, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=0.5, gamma=1, kernel=rbf, total=   2.7s
# [CV] C=0.5, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=0.5, gamma=1, kernel=rbf, total=   2.7s
# [CV] C=0.5, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=0.5, gamma=1, kernel=rbf, total=   2.7s
# [CV] C=0.5, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=0.5, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=0.5, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=0.5, gamma=1, kernel=rbf, total=   2.7s
# [CV] C=0.5, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=0.5, gamma=1, kernel=rbf, total=   2.7s
# [CV] C=0.5, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=0.5, gamma=1, kernel=rbf, total=   2.7s
# [CV] C=0.5, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=0.5, gamma=1, kernel=rbf, total=   2.6s
# [CV] C=0.5, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=0.5, gamma=1, kernel=rbf, total=   2.6s
# [CV] C=0.5, gamma=0.1, kernel=rbf ....................................
# [CV] ..................... C=0.5, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=0.5, gamma=0.1, kernel=rbf ....................................
# [CV] ..................... C=0.5, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=0.5, gamma=0.1, kernel=rbf ....................................
# [CV] ..................... C=0.5, gamma=0.1, kernel=rbf, total=   2.8s
# [CV] C=0.5, gamma=0.1, kernel=rbf ....................................
# [CV] ..................... C=0.5, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=0.5, gamma=0.1, kernel=rbf ....................................
# [CV] ..................... C=0.5, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=0.5, gamma=0.1, kernel=rbf ....................................
# [CV] ..................... C=0.5, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=0.5, gamma=0.1, kernel=rbf ....................................
# [CV] ..................... C=0.5, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=0.5, gamma=0.1, kernel=rbf ....................................
# [CV] ..................... C=0.5, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=0.5, gamma=0.1, kernel=rbf ....................................
# [CV] ..................... C=0.5, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=0.5, gamma=0.1, kernel=rbf ....................................
# [CV] ..................... C=0.5, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=0.5, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=0.5, gamma=0.01, kernel=rbf, total=   2.9s
# [CV] C=0.5, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=0.5, gamma=0.01, kernel=rbf, total=   2.9s
# [CV] C=0.5, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=0.5, gamma=0.01, kernel=rbf, total=   2.9s
# [CV] C=0.5, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=0.5, gamma=0.01, kernel=rbf, total=   2.9s
# [CV] C=0.5, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=0.5, gamma=0.01, kernel=rbf, total=   2.9s
# [CV] C=0.5, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=0.5, gamma=0.01, kernel=rbf, total=   2.9s
# [CV] C=0.5, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=0.5, gamma=0.01, kernel=rbf, total=   2.9s
# [CV] C=0.5, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=0.5, gamma=0.01, kernel=rbf, total=   2.9s
# [CV] C=0.5, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=0.5, gamma=0.01, kernel=rbf, total=   2.9s
# [CV] C=0.5, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=0.5, gamma=0.01, kernel=rbf, total=   2.9s
# [CV] C=0.5, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=0.5, gamma=0.001, kernel=rbf, total=   2.4s
# [CV] C=0.5, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=0.5, gamma=0.001, kernel=rbf, total=   2.4s
# [CV] C=0.5, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=0.5, gamma=0.001, kernel=rbf, total=   2.4s
# [CV] C=0.5, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=0.5, gamma=0.001, kernel=rbf, total=   2.3s
# [CV] C=0.5, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=0.5, gamma=0.001, kernel=rbf, total=   2.4s
# [CV] C=0.5, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=0.5, gamma=0.001, kernel=rbf, total=   2.4s
# [CV] C=0.5, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=0.5, gamma=0.001, kernel=rbf, total=   2.4s
# [CV] C=0.5, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=0.5, gamma=0.001, kernel=rbf, total=   2.5s
# [CV] C=0.5, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=0.5, gamma=0.001, kernel=rbf, total=   2.3s
# [CV] C=0.5, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=0.5, gamma=0.001, kernel=rbf, total=   2.4s
# [CV] C=0.5, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=0.5, gamma=0.0001, kernel=rbf, total=   1.8s
# [CV] C=0.5, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=0.5, gamma=0.0001, kernel=rbf, total=   1.8s
# [CV] C=0.5, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=0.5, gamma=0.0001, kernel=rbf, total=   1.8s
# [CV] C=0.5, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=0.5, gamma=0.0001, kernel=rbf, total=   1.8s
# [CV] C=0.5, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=0.5, gamma=0.0001, kernel=rbf, total=   1.8s
# [CV] C=0.5, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=0.5, gamma=0.0001, kernel=rbf, total=   1.8s
# [CV] C=0.5, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=0.5, gamma=0.0001, kernel=rbf, total=   1.8s
# [CV] C=0.5, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=0.5, gamma=0.0001, kernel=rbf, total=   1.8s
# [CV] C=0.5, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=0.5, gamma=0.0001, kernel=rbf, total=   1.8s
# [CV] C=0.5, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=0.5, gamma=0.0001, kernel=rbf, total=   1.7s
# [CV] C=3, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=3, gamma=scale, kernel=rbf, total=   1.5s
# [CV] C=3, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=3, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=3, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=3, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=3, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=3, gamma=scale, kernel=rbf, total=   1.7s
# [CV] C=3, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=3, gamma=scale, kernel=rbf, total=   1.7s
# [CV] C=3, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=3, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=3, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=3, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=3, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=3, gamma=scale, kernel=rbf, total=   1.5s
# [CV] C=3, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=3, gamma=scale, kernel=rbf, total=   1.5s
# [CV] C=3, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=3, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=3, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=3, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=3, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=3, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=3, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=3, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=3, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=3, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=3, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=3, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=3, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=3, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=3, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=3, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=3, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=3, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=3, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=3, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=3, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=3, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=3, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=3, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=3, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=3, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=3, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=3, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=3, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=3, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=3, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=3, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=3, gamma=0.001, kernel=rbf ....................................
# [CV] ..................... C=3, gamma=0.001, kernel=rbf, total=   2.3s
# [CV] C=3, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=3, gamma=0.0001, kernel=rbf, total=   2.1s
# [CV] C=3, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=3, gamma=0.0001, kernel=rbf, total=   2.1s
# [CV] C=3, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=3, gamma=0.0001, kernel=rbf, total=   2.1s
# [CV] C=3, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=3, gamma=0.0001, kernel=rbf, total=   2.1s
# [CV] C=3, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=3, gamma=0.0001, kernel=rbf, total=   2.2s
# [CV] C=3, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=3, gamma=0.0001, kernel=rbf, total=   2.0s
# [CV] C=3, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=3, gamma=0.0001, kernel=rbf, total=   2.1s
# [CV] C=3, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=3, gamma=0.0001, kernel=rbf, total=   2.1s
# [CV] C=3, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=3, gamma=0.0001, kernel=rbf, total=   2.1s
# [CV] C=3, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=3, gamma=0.0001, kernel=rbf, total=   2.1s
# [CV] C=5, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=5, gamma=scale, kernel=rbf, total=   1.5s
# [CV] C=5, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=5, gamma=scale, kernel=rbf, total=   1.5s
# [CV] C=5, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=5, gamma=scale, kernel=rbf, total=   1.5s
# [CV] C=5, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=5, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=5, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=5, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=5, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=5, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=5, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=5, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=5, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=5, gamma=scale, kernel=rbf, total=   1.5s
# [CV] C=5, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=5, gamma=scale, kernel=rbf, total=   1.5s
# [CV] C=5, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=5, gamma=scale, kernel=rbf, total=   1.7s
# [CV] C=5, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=5, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=5, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=5, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=5, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=5, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=5, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=5, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=5, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=5, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=5, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=5, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=5, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=5, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=5, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=5, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=5, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=5, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=5, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=5, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=5, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=5, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=5, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=5, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=5, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=5, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=5, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=5, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=5, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=5, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=5, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=5, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=5, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=5, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=5, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=5, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=5, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=5, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=5, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=5, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=5, gamma=0.01, kernel=rbf .....................................
# [CV] ...................... C=5, gamma=0.01, kernel=rbf, total=   3.0s
# [CV] C=5, gamma=0.01, kernel=rbf .....................................
# [CV] ...................... C=5, gamma=0.01, kernel=rbf, total=   3.0s
# [CV] C=5, gamma=0.01, kernel=rbf .....................................
# [CV] ...................... C=5, gamma=0.01, kernel=rbf, total=   3.0s
# [CV] C=5, gamma=0.01, kernel=rbf .....................................
# [CV] ...................... C=5, gamma=0.01, kernel=rbf, total=   3.0s
# [CV] C=5, gamma=0.01, kernel=rbf .....................................
# [CV] ...................... C=5, gamma=0.01, kernel=rbf, total=   3.2s
# [CV] C=5, gamma=0.01, kernel=rbf .....................................
# [CV] ...................... C=5, gamma=0.01, kernel=rbf, total=   3.0s
# [CV] C=5, gamma=0.01, kernel=rbf .....................................
# [CV] C=7, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=7, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=7, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=7, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=7, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=7, gamma=scale, kernel=rbf, total=   1.5s
# [CV] C=7, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=7, gamma=scale, kernel=rbf, total=   1.5s
# [CV] C=7, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=7, gamma=scale, kernel=rbf, total=   1.7s
# [CV] C=7, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=7, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=7, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=7, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=7, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=7, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=7, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=7, gamma=scale, kernel=rbf, total=   1.5s
# [CV] C=7, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=7, gamma=scale, kernel=rbf, total=   1.5s
# [CV] C=7, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=7, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=7, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=7, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=7, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=7, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=7, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=7, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=7, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=7, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=7, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=7, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=7, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=7, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=7, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=7, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=7, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=7, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=7, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=7, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=7, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=7, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=7, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=7, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=7, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=7, gamma=0.1, kernel=rbf, total=   2.8s
# [CV] C=7, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=7, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=7, gamma=0.1, kernel=rbf ......................................
# [CV] C=7, gamma=0.001, kernel=rbf ....................................
# [CV] ..................... C=7, gamma=0.001, kernel=rbf, total=   2.4s
# [CV] C=7, gamma=0.001, kernel=rbf ....................................
# [CV] ..................... C=7, gamma=0.001, kernel=rbf, total=   2.4s
# [CV] C=7, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=7, gamma=0.0001, kernel=rbf, total=   2.4s
# [CV] C=7, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=7, gamma=0.0001, kernel=rbf, total=   2.2s
# [CV] C=7, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=7, gamma=0.0001, kernel=rbf, total=   2.4s
# [CV] C=7, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=7, gamma=0.0001, kernel=rbf, total=   2.4s
# [CV] C=7, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=7, gamma=0.0001, kernel=rbf, total=   2.4s
# [CV] C=7, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=7, gamma=0.0001, kernel=rbf, total=   2.3s
# [CV] C=7, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=7, gamma=0.0001, kernel=rbf, total=   2.4s
# [CV] C=7, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=7, gamma=0.0001, kernel=rbf, total=   2.4s
# [CV] C=7, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=7, gamma=0.0001, kernel=rbf, total=   2.4s
# [CV] C=7, gamma=0.0001, kernel=rbf ...................................
# [CV] .................... C=7, gamma=0.0001, kernel=rbf, total=   2.4s
# [CV] C=9, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=9, gamma=scale, kernel=rbf, total=   1.7s
# [CV] C=9, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=9, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=9, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=9, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=9, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=9, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=9, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=9, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=9, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=9, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=9, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=9, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=9, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=9, gamma=scale, kernel=rbf, total=   1.7s
# [CV] C=9, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=9, gamma=scale, kernel=rbf, total=   1.7s
# [CV] C=9, gamma=scale, kernel=rbf ....................................
# [CV] ..................... C=9, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=9, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=9, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=9, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=9, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=9, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=9, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=9, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=9, gamma=1, kernel=rbf, total=   2.9s
# [CV] C=9, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=9, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=9, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=9, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=9, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=9, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=9, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=9, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=9, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=9, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=9, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=9, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=9, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=9, gamma=0.1, kernel=rbf, total=   2.8s
# [CV] C=9, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=9, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=9, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=9, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=9, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=9, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=9, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=9, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=9, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=9, gamma=0.1, kernel=rbf, total=   2.8s
# [CV] C=9, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=9, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=9, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=9, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=9, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=9, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=9, gamma=0.1, kernel=rbf ......................................
# [CV] ....................... C=9, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=9, gamma=0.01, kernel=rbf .....................................
# [CV] ...................... C=9, gamma=0.01, kernel=rbf, total=   3.1s
# [CV] C=9, gamma=0.01, kernel=rbf .....................................
# [CV] ...................... C=9, gamma=0.01, kernel=rbf, total=   3.1s
# [CV] C=9, gamma=0.01, kernel=rbf .....................................
# [CV] ...................... C=9, gamma=0.01, kernel=rbf, total=   3.1s
# [CV] C=9, gamma=0.01, kernel=rbf .....................................
# [CV] ...................... C=9, gamma=0.01, kernel=rbf, total=   3.0s
# [CV] C=9, gamma=0.01, kernel=rbf .....................................
# [CV] ...................... C=9, gamma=0.01, kernel=rbf, total=   3.0s
# [CV] C=9, gamma=0.01, kernel=rbf .....................................
# [CV] ...................... C=9, gamma=0.01, kernel=rbf, total=   3.2s
# [CV] .................... C=9, gamma=0.0001, kernel=rbf, total=   2.4s
# [CV] C=10, gamma=scale, kernel=rbf ...................................
# [CV] .................... C=10, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=10, gamma=scale, kernel=rbf ...................................
# [CV] .................... C=10, gamma=scale, kernel=rbf, total=   1.5s
# [CV] C=10, gamma=scale, kernel=rbf ...................................
# [CV] .................... C=10, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=10, gamma=scale, kernel=rbf ...................................
# [CV] .................... C=10, gamma=scale, kernel=rbf, total=   1.5s
# [CV] C=10, gamma=scale, kernel=rbf ...................................
# [CV] .................... C=10, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=10, gamma=scale, kernel=rbf ...................................
# [CV] .................... C=10, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=10, gamma=scale, kernel=rbf ...................................
# [CV] .................... C=10, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=10, gamma=scale, kernel=rbf ...................................
# [CV] .................... C=10, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=10, gamma=scale, kernel=rbf ...................................
# [CV] .................... C=10, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=10, gamma=scale, kernel=rbf ...................................
# [CV] .................... C=10, gamma=scale, kernel=rbf, total=   1.6s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........................ C=10, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........................ C=10, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........................ C=10, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........................ C=10, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........................ C=10, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........................ C=10, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........................ C=10, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........................ C=10, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........................ C=10, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........................ C=10, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ...................... C=10, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ...................... C=10, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ...................... C=10, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ...................... C=10, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ...................... C=10, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ...................... C=10, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ...................... C=10, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ...................... C=10, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ...................... C=10, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ...................... C=10, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ..................... C=10, gamma=0.01, kernel=rbf, total=   3.0s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ..................... C=10, gamma=0.01, kernel=rbf, total=   3.0s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ..................... C=10, gamma=0.01, kernel=rbf, total=   3.0s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ..................... C=10, gamma=0.01, kernel=rbf, total=   3.0s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ..................... C=10, gamma=0.01, kernel=rbf, total=   3.2s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ..................... C=10, gamma=0.01, kernel=rbf, total=   3.1s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ..................... C=10, gamma=0.01, kernel=rbf, total=   3.2s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ..................... C=10, gamma=0.01, kernel=rbf, total=   3.1s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ..................... C=10, gamma=0.01, kernel=rbf, total=   3.0s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ..................... C=10, gamma=0.01, kernel=rbf, total=   3.0s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] .................... C=10, gamma=0.001, kernel=rbf, total=   2.5s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] .................... C=10, gamma=0.001, kernel=rbf, total=   2.4s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] .................... C=10, gamma=0.001, kernel=rbf, total=   2.5s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] .................... C=10, gamma=0.001, kernel=rbf, total=   2.4s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] .................... C=10, gamma=0.001, kernel=rbf, total=   2.4s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] .................... C=10, gamma=0.001, kernel=rbf, total=   2.4s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] .................... C=10, gamma=0.001, kernel=rbf, total=   2.5s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] .................... C=10, gamma=0.001, kernel=rbf, total=   2.5s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] .................... C=10, gamma=0.001, kernel=rbf, total=   2.4s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] .................... C=10, gamma=0.001, kernel=rbf, total=   2.4s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ................... C=10, gamma=0.0001, kernel=rbf, total=   2.4s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ................... C=10, gamma=0.0001, kernel=rbf, total=   2.3s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ................... C=10, gamma=0.0001, kernel=rbf, total=   2.4s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ................... C=10, gamma=0.0001, kernel=rbf, total=   2.4s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ................... C=10, gamma=0.0001, kernel=rbf, total=   2.5s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ................... C=10, gamma=0.0001, kernel=rbf, total=   2.4s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ................... C=10, gamma=0.0001, kernel=rbf, total=   2.5s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ................... C=10, gamma=0.0001, kernel=rbf, total=   2.4s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ................... C=10, gamma=0.0001, kernel=rbf, total=   2.4s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ................... C=10, gamma=0.0001, kernel=rbf, total=   2.4s
# [CV] C=100, gamma=scale, kernel=rbf ..................................
# [CV] ................... C=100, gamma=scale, kernel=rbf, total=   1.9s
# [CV] C=100, gamma=scale, kernel=rbf ..................................
# [CV] ................... C=100, gamma=scale, kernel=rbf, total=   2.0s
# [CV] C=100, gamma=scale, kernel=rbf ..................................
# [CV] ................... C=100, gamma=scale, kernel=rbf, total=   1.9s
# [CV] C=100, gamma=scale, kernel=rbf ..................................
# [CV] ................... C=100, gamma=scale, kernel=rbf, total=   1.8s
# [CV] C=100, gamma=scale, kernel=rbf ..................................
# [CV] ................... C=100, gamma=scale, kernel=rbf, total=   1.9s
# [CV] C=100, gamma=scale, kernel=rbf ..................................
# [CV] ................... C=100, gamma=scale, kernel=rbf, total=   2.1s
# [CV] C=100, gamma=scale, kernel=rbf ..................................
# [CV] ................... C=100, gamma=scale, kernel=rbf, total=   2.1s
# [CV] C=100, gamma=scale, kernel=rbf ..................................
# [CV] ................... C=100, gamma=scale, kernel=rbf, total=   2.0s
# [CV] C=100, gamma=scale, kernel=rbf ..................................
# [CV] ................... C=100, gamma=scale, kernel=rbf, total=   1.7s
# [CV] C=100, gamma=scale, kernel=rbf ..................................
# [CV] ................... C=100, gamma=scale, kernel=rbf, total=   2.1s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=100, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=100, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=100, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=100, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=100, gamma=1, kernel=rbf, total=   2.7s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=100, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=100, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=100, gamma=1, kernel=rbf, total=   2.7s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=100, gamma=1, kernel=rbf, total=   2.8s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=100, gamma=1, kernel=rbf, total=   2.7s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ..................... C=100, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ..................... C=100, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ..................... C=100, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ..................... C=100, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ..................... C=100, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ..................... C=100, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ..................... C=100, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ..................... C=100, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ..................... C=100, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ..................... C=100, gamma=0.1, kernel=rbf, total=   2.7s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=100, gamma=0.01, kernel=rbf, total=   3.1s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=100, gamma=0.01, kernel=rbf, total=   3.0s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=100, gamma=0.01, kernel=rbf, total=   3.0s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=100, gamma=0.01, kernel=rbf, total=   3.2s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=100, gamma=0.01, kernel=rbf, total=   3.0s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=100, gamma=0.01, kernel=rbf, total=   3.2s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=100, gamma=0.01, kernel=rbf, total=   3.2s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=100, gamma=0.01, kernel=rbf, total=   3.2s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=100, gamma=0.01, kernel=rbf, total=   3.1s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=100, gamma=0.01, kernel=rbf, total=   3.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=100, gamma=0.001, kernel=rbf, total=   4.1s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=100, gamma=0.001, kernel=rbf, total=   4.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=100, gamma=0.001, kernel=rbf, total=   4.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=100, gamma=0.001, kernel=rbf, total=   4.1s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=100, gamma=0.001, kernel=rbf, total=   4.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=100, gamma=0.001, kernel=rbf, total=   4.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=100, gamma=0.001, kernel=rbf, total=   4.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=100, gamma=0.001, kernel=rbf, total=   3.9s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=100, gamma=0.001, kernel=rbf, total=   4.0s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=100, gamma=0.001, kernel=rbf, total=   3.9s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=100, gamma=0.0001, kernel=rbf, total=   3.8s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=100, gamma=0.0001, kernel=rbf, total=   3.6s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=100, gamma=0.0001, kernel=rbf, total=   4.1s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=100, gamma=0.0001, kernel=rbf, total=   3.7s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=100, gamma=0.0001, kernel=rbf, total=   3.5s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=100, gamma=0.0001, kernel=rbf, total=   3.2s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=100, gamma=0.0001, kernel=rbf, total=   3.4s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=100, gamma=0.0001, kernel=rbf, total=   4.4s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=100, gamma=0.0001, kernel=rbf, total=   3.9s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] .................. C=100, gamma=0.0001, kernel=rbf, total=   3.4s
# [Parallel(n_jobs=1)]: Done 420 out of 420 | elapsed: 17.8min finished
# GridSearchCV(cv=10, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid=[{'C': [0.5, 3, 5, 7, 9, 10, 100],
#                           'gamma': ['scale', 1, 0.1, 0.01, 0.001, 0.0001],
#                           'kernel': ['rbf']}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='accuracy', verbose=2)

# %%
#imprimer les meilleurs paramètres de la méthode de validation croisée
print(optimal_params.best_params_)
# Out:
# {'C': 3, 'gamma': 0.0001, 'kernel': 'rbf'}

# %%
model2=SVC(kernel='rbf',C=3,gamma=0.0001)

# %%
model2.fit(X_train,y_train)
# Out:
# SVC(C=3, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.0001, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
prediction_test2 = model2.predict(X_test)

# %%
#ici nous voyons que l'accuarcy augment en  appliquant les paramètres de la méthode de validation croisée
print ("Accuracy = ", metrics.accuracy_score(y_test, prediction_test2))
# Out:
# Accuracy =  0.7375

# %% [markdown]
# ################################################################################################################################################################

# %%
# sauvegarder le modéle dans le disque 
filename = '/content/Drive/MyDrive/e-comerce model/model2_SVM_ecommerce_73-75.sav'
pickle.dump(model2, open(filename, 'wb'))

# %%
#maintenant nous allons essayer votre modèle enregistré sur un autre ensemble


loaded_model = pickle.load(open(filename, 'rb'))

# %%
prediction_loaded_model = loaded_model.predict(X_test)
print ("Accuracy = ", metrics.accuracy_score(y_test, prediction_loaded_model))
# Out:
# Accuracy =  0.7375

# %%
cm = metrics.confusion_matrix(y_test,prediction_loaded_model)
print(cm)
# Out:
# [[772  12]
#  [408 408]]

# %%
# !pip install AutoViz
# !pip install xlrd

# %%
#importation de la classe Autoviz
from autoviz.AutoViz_Class import AutoViz_Class

#Initioaliser la classe Autovis
AV = AutoViz_Class()
# Out:
# Imported AutoViz_Class version: 0.0.81. Call using:
#     from autoviz.AutoViz_Class import AutoViz_Class
#     AV = AutoViz_Class()
#     AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)
# Note: verbose=0 or 1 generates charts and displays them in your local Jupyter notebook.
#       verbose=2 saves plots in your local machine under AutoViz_Plots directory and does not display charts.

# %%
#dans le modèle svm, j'ai visualisé les informations sur l'ensemble de données et dans le modèle d'arbre de décision, j'ai visualisé les informations sur la variable cible `` atteinte à temps ''
#grâce à la bibliothèque autoviz pour faciliter la visualisation des données
dftc = AV.AutoViz('/content/Drive/MyDrive/e-comerce dataset/data.csv')
# Out:
# Shape of your Data Set: (10999, 12)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     Number of Numeric Columns =  0
#     Number of Integer-Categorical Columns =  6
#     Number of String-Categorical Columns =  3
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  1
#     Number of Numeric-Boolean Columns =  1
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     12 Predictors classified...
#         This does not include the Target column(s)
#         1 variables removed since they were ID or low-information variables
# Number of All Scatter Plots = 21
# Could not draw Distribution Plot
# Time to run AutoViz (in seconds) = 11.409
#
#  ###################### VISUALIZATION Completed ########################
